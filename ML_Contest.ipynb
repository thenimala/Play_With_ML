# %%
import pandas as pd

# %%
df=pd.read_csv('fc_data_0step.csv')

# %%
df.head()

# %%
df.describe()

# %%
df.isnull().values.any()
# Out:
# False

# %%
df.size
# Out:
# 2616085

# %% [markdown]
# Question No 1: Here In this DATASET we set that it has 895 columns and 2923 row. Also see that this dataset contains not any single null values..
#
# So the total number of data is = 2616085

# %%
df=pd.read_csv('fc_labels_0step.csv')

# %%
df0=df[df['2']==0]
df0.shape
# Out:
# (580, 1)

# %%
df1=df[df['2']==1]
df1.shape
# Out:
# (1158, 1)

# %%
df2=df[df['2']==2]
df2.shape
# Out:
# (560, 1)

# %%
df3=df[df['2']==3]
df3.shape
# Out:
# (625, 1)

# %% [markdown]
# Question No:2-
#     class 1 contains 580 data
#     class 2 contains 1158 data
#     class 3 contains 560 data
#     class 4 contains 625 data

# %%
df=pd.read_csv('fc_data_0step.csv')

# %%
df.mean()
# Out:
# -1.3194      0.000452
# -1.0065      0.000344
# -1.3701      0.000469
# 1.1945      -0.000409
# 0.91843     -0.000314
# 0.40126     -0.000137
# 0.45126     -0.000155
# 0.94609     -0.000324
# 0.27302     -0.000093
# -1.3883      0.000475
# 0.87686     -0.000300
# 0.58391     -0.000200
# 0.93681     -0.000320
# 0.51558     -0.000176
# -1.0405      0.000355
# -1.7103      0.000585
# -0.95145     0.000325
# -0.80023     0.000274
# -1.1068      0.000379
# -0.9313      0.000319
# -1.1772      0.000403
# -1.1013      0.000376
# -1.0728      0.000367
# -0.93915     0.000321
# -0.84775     0.000290
# -0.93722     0.000321
# -0.91166     0.000312
# -1.0017      0.000342
# -0.83837     0.000287
# -0.6795      0.000232
#                ...
# -0.41324     0.000141
# -0.67802     0.000232
# -0.52328     0.000179
# -0.53121     0.000182
# -0.49834     0.000171
# -0.56645     0.000194
# -0.8411      0.000288
# -1.2911      0.000442
# -1.1781.1    0.000403
# -1.2466      0.000427
# ...

# %%
df.std()
# Out:
# -1.3194      0.998332
# -1.0065      0.998457
# -1.3701      0.998308
# 1.1945       0.998385
# 0.91843      0.998486
# 0.40126      0.998602
# 0.45126      0.998595
# 0.94609      0.998475
# 0.27302      0.998618
# -1.3883      0.998300
# 0.87686      0.998499
# 0.58391      0.998572
# 0.93681      0.998480
# 0.51558      0.998585
# -1.0405      0.998445
# -1.7103      0.998129
# -0.95145     0.998475
# -0.80023     0.998521
# -1.1068      0.998421
# -0.9313      0.998481
# -1.1772      0.998394
# -1.1013      0.998422
# -1.0728      0.998434
# -0.93915     0.998479
# -0.84775     0.998506
# -0.93722     0.998480
# -0.91166     0.998489
# -1.0017      0.998458
# -0.83837     0.998510
# -0.6795      0.998551
#                ...
# -0.41324     0.998602
# -0.67802     0.998551
# -0.52328     0.998584
# -0.53121     0.998581
# -0.49834     0.998588
# -0.56645     0.998575
# -0.8411      0.998511
# -1.2911      0.998344
# -1.1781.1    0.998391
# -1.2466      0.998364
# ...

# %%
df.describe()
# Out:
#            -1.3194      -1.0065      -1.3701       1.1945      0.91843  \
# count  2923.000000  2923.000000  2923.000000  2923.000000  2923.000000
# mean      0.000452     0.000344     0.000469    -0.000409    -0.000314
# std       0.998332     0.998457     0.998308     0.998385     0.998486
# min      -3.053300    -2.343700    -4.419600    -4.622800    -5.933500
# 25%      -0.684655    -0.803975    -0.562625    -0.607330    -0.501320
# 50%      -0.082601    -0.035495     0.158670     0.217380     0.091322
# 75%       0.569655     0.696000     0.707720     0.746010     0.627565
# max       4.902500     4.024000     3.149900     2.258400     3.673300
#
#            0.40126      0.45126      0.94609      0.27302      -1.3883  \
# count  2923.000000  2923.000000  2923.000000  2923.000000  2923.000000
# mean     -0.000137    -0.000155    -0.000324    -0.000093     0.000475
# std       0.998602     0.998595     0.998475     0.998618     0.998300
# ...

# %%
df2=df.iloc[[36,207]]

# %%
df2
# Out:
#      -1.3194  -1.0065   -1.3701   1.1945  0.91843  0.40126  0.45126   0.94609  \
# 36   1.59660   1.0286  0.019564 -0.93379  0.11954 -0.41893 -1.45090 -1.936000
# 207  0.21416   0.4564 -0.729010 -0.38777 -1.42900 -0.74921 -0.21852  0.049013
#
#      0.27302  -1.3883    ...     -1.2614  -1.3379  -1.1745  -0.86053  -1.3305  \
# 36  -0.53185  -1.2831    ...     0.39413  0.76192  0.20824   0.15856   1.5158
# 207 -0.24455  -1.7015    ...     3.00020  3.21120  2.19800   2.78070   1.3899
#
#       -1.3541  -0.79275  -0.85486  -1.4075  -0.80598
# 36  -0.019498  0.083909   0.22552 -0.10424 -0.078338
# 207  3.134100  2.892300   1.18780  2.51420  3.081300
#
# [2 rows x 895 columns]

# %%
from matplotlib import pyplot as plt
# %matplotlib inline
import numpy as np

# %%
df2.describe()
# Out:
#         -1.3194   -1.0065   -1.3701    1.1945   0.91843   0.40126   0.45126  \
# count  2.000000  2.000000  2.000000  2.000000  2.000000  2.000000  2.000000
# mean   0.905380  0.742500 -0.354723 -0.660780 -0.654730 -0.584070 -0.834710
# std    0.977533  0.404607  0.529322  0.386094  1.094983  0.233543  0.871424
# min    0.214160  0.456400 -0.729010 -0.933790 -1.429000 -0.749210 -1.450900
# 25%    0.559770  0.599450 -0.541867 -0.797285 -1.041865 -0.666640 -1.142805
# 50%    0.905380  0.742500 -0.354723 -0.660780 -0.654730 -0.584070 -0.834710
# 75%    1.250990  0.885550 -0.167580 -0.524275 -0.267595 -0.501500 -0.526615
# max    1.596600  1.028600  0.019564 -0.387770  0.119540 -0.418930 -0.218520
#
#         0.94609   0.27302   -1.3883    ...      -1.2614   -1.3379   -1.1745  \
# count  2.000000  2.000000  2.000000    ...     2.000000  2.000000  2.000000
# mean  -0.943493 -0.388200 -1.492300    ...     1.697165  1.986560  1.203120
# ...

# %%
df2.plot(x=36, y=207, kind='scatter')

# %% [markdown]
# Question 4: Dataset Columns is not clear to me. I try many different plot but we didn't find any pattern.
